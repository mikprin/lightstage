# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %% [markdown]
# # camera caps

# %%
df20ms = pd.read_csv('data/20ms_nocap.csv', delimiter=';')
df20ms_2x470u = pd.read_csv('data/20ms_2x470u.csv', delimiter=';')
df20ms_4x470u = pd.read_csv('data/20ms_4x470u.csv', delimiter=';')
df20ms_5x470u = pd.read_csv('data/20ms_5x470u.csv', delimiter=';')
df20ms_470u = pd.read_csv('data/20ms_470u.csv', delimiter=';')

# %%
fig=plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')
ax2 = plt.axes()
ax2.plot(df20ms.iloc[:,0],df20ms.iloc[:,1],label="NO_CAP",linewidth=3.0)
ax2.plot(df20ms_470u.iloc[:,0],df20ms_470u.iloc[:,1],label="470u")
ax2.plot(df20ms_2x470u.iloc[:,0],df20ms_2x470u.iloc[:,1],label="2x470u",linewidth=2.0)
ax2.plot(df20ms_4x470u.iloc[:,0],df20ms_4x470u.iloc[:,1],label="4x470u",linewidth=2.0)
ax2.plot(df20ms_5x470u.iloc[:,0],df20ms_5x470u.iloc[:,1],label="5x470u",linewidth=2.0)

#ax2.legend(['A simple line'])
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('Time relative to osciloscope')
plt.ylabel('Voltage')
#plt.xlim(left= 0.15 ) 
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
#with pd.option_context('display.precision', 10):
#    print(df)
len(Current_typ_temp.iloc[:,0])
# Out:
# 51

# %%
t = Current_typ_temp.iloc[:,0]
fig=plt.figure(figsize=(8,8), dpi= 100, facecolor='w', edgecolor='k')
ax2 = plt.axes()
line_Current_typ_temp, = ax2.plot(t,Current_typ_temp.iloc[:,1],label="typ_temp",linewidth=3.0)
line_Current_slow_temp, = ax2.plot(t,Current_slow_temp.iloc[:,1],label="slow")
line_Current_fast_temp, = ax2.plot(t,Current_fast_temp.iloc[:,1],label="fast")
line_Current_rmin_temp, = ax2.plot(t,Current_rmin_temp.iloc[:,1],label="rmin")
line_Current_rmax_temp, = ax2.plot(t,Current_rmax_temp.iloc[:,1],label="rmax")
#ax2.legend(['A simple line'])
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('Температура, C')
plt.ylabel('Ток, A')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
Ids_temp = pd.read_csv('imgs/14u_2u_temp_VDS.csv', delimiter=',')

# %%
Ids_temp
# Out:
#     /M9/S (temp=-20) X  /M9/S (temp=-20) Y  /M9/S (temp=5) X  \
# 0                  0.0        2.666160e-05               0.0
# 1                  0.1        2.665536e-05               0.1
# 2                  0.2        2.664887e-05               0.2
# 3                  0.3        2.664212e-05               0.3
# 4                  0.4        2.663508e-05               0.4
# 5                  0.5        2.662774e-05               0.5
# 6                  0.6        2.662008e-05               0.6
# 7                  0.7        2.661207e-05               0.7
# 8                  0.8        2.660370e-05               0.8
# 9                  0.9        2.659493e-05               0.9
# 10                 1.0        2.658573e-05               1.0
# 11                 1.1        2.657608e-05               1.1
# 12                 1.2        2.656592e-05               1.2
# 13                 1.3        2.655524e-05               1.3
# 14                 1.4        2.654396e-05               1.4
# 15                 1.5        2.653206e-05               1.5
# 16                 1.6        2.651947e-05               1.6
# 17                 1.7        2.650612e-05               1.7
# 18                 1.8        2.649195e-05               1.8
# 19                 1.9        2.647688e-05               1.9
# 20                 2.0        2.646081e-05               2.0
# 21                 2.1        2.644363e-05               2.1
# 22                 2.2        2.642523e-05               2.2
# 23                 2.3        2.640547e-05               2.3
# 24                 2.4        2.638419e-05               2.4
# 25                 2.5        2.636119e-05               2.5
# 26                 2.6        2.633626e-05               2.6
# 27                 2.7        2.630914e-05               2.7
# 28                 2.8        2.627952e-05               2.8
# 29                 2.9        2.624702e-05               2.9
# 30                 3.0        2.621119e-05               3.0
# 31                 3.1        2.617148e-05               3.1
# 32                 3.2        2.612721e-05               3.2
# 33                 3.3        2.607751e-05               3.3
# 34                 3.4        2.602129e-05               3.4
# 35                 3.5        2.595713e-05               3.5
# 36                 3.6        2.588316e-05               3.6
# 37                 3.7        2.579686e-05               3.7
# 38                 3.8        2.569471e-05               3.8
# 39                 3.9        2.557171e-05               3.9
# 40                 4.0        2.542045e-05               4.0
# 41                 4.1        2.522941e-05               4.1
# 42                 4.2        2.497986e-05               4.2
# 43                 4.3        2.463934e-05               4.3
# 44                 4.4        2.414789e-05               4.4
# 45                 4.5        2.338774e-05               4.5
# 46                 4.6        2.212072e-05               4.6
# 47                 4.7        1.989043e-05               4.7
# 48                 4.8        1.597617e-05               4.8
# 49                 4.9        9.560121e-06               4.9
# 50                 5.0       -7.623297e-21               5.0
#
#     /M9/S (temp=5) Y  /M9/S (temp=30) X  /M9/S (temp=30) Y  /M9/S (temp=55) X  \
# 0       2.677734e-05                0.0           0.000027                0.0
# 1       2.677051e-05                0.1           0.000027                0.1
# 2       2.676340e-05                0.2           0.000027                0.2
# 3       2.675600e-05                0.3           0.000027                0.3
# 4       2.674829e-05                0.4           0.000027                0.4
# 5       2.674025e-05                0.5           0.000027                0.5
# 6       2.673186e-05                0.6           0.000027                0.6
# 7       2.672310e-05                0.7           0.000027                0.7
# 8       2.671392e-05                0.8           0.000027                0.8
# 9       2.670432e-05                0.9           0.000027                0.9
# 10      2.669425e-05                1.0           0.000027                1.0
# 11      2.668368e-05                1.1           0.000027                1.1
# 12      2.667257e-05                1.2           0.000027                1.2
# 13      2.666087e-05                1.3           0.000027                1.3
# 14      2.664854e-05                1.4           0.000027                1.4
# 15      2.663552e-05                1.5           0.000027                1.5
# 16      2.662175e-05                1.6           0.000027                1.6
# 17      2.660716e-05                1.7           0.000027                1.7
# 18      2.659168e-05                1.8           0.000027                1.8
# 19      2.657521e-05                1.9           0.000027                1.9
# 20      2.655767e-05                2.0           0.000027                2.0
# 21      2.653893e-05                2.1           0.000027                2.1
# 22      2.651887e-05                2.2           0.000027                2.2
# 23      2.649734e-05                2.3           0.000027                2.3
# 24      2.647416e-05                2.4           0.000027                2.4
# 25      2.644915e-05                2.5           0.000027                2.5
# 26      2.642205e-05                2.6           0.000026                2.6
# 27      2.639259e-05                2.7           0.000026                2.7
# 28      2.636045e-05                2.8           0.000026                2.8
# 29      2.632522e-05                2.9           0.000026                2.9
# 30      2.628644e-05                3.0           0.000026                3.0
# 31      2.624350e-05                3.1           0.000026                3.1
# 32      2.619569e-05                3.2           0.000026                3.2
# 33      2.614210e-05                3.3           0.000026                3.3
# 34      2.608155e-05                3.4           0.000026                3.4
# 35      2.601256e-05                3.5           0.000026                3.5
# 36      2.593313e-05                3.6           0.000026                3.6
# 37      2.584057e-05                3.7           0.000026                3.7
# 38      2.573114e-05                3.8           0.000026                3.8
# 39      2.559947e-05                3.9           0.000026                3.9
# 40      2.543753e-05                4.0           0.000025                4.0
# 41      2.523282e-05                4.1           0.000025                4.1
# 42      2.496473e-05                4.2           0.000025                4.2
# 43      2.459723e-05                4.3           0.000025                4.3
# 44      2.406340e-05                4.4           0.000024                4.4
# 45      2.323276e-05                4.5           0.000023                4.5
# 46      2.185020e-05                4.6           0.000022                4.6
# 47      1.946212e-05                4.7           0.000019                4.7
# 48      1.542754e-05                4.8           0.000015                4.8
# 49      9.097605e-06                4.9           0.000009                4.9
# 50     -6.988022e-21                5.0           0.000000                5.0
#
#     /M9/S (temp=55) Y  /M9/S (temp=80) X  /M9/S (temp=80) Y
# 0            0.000027                0.0       2.695203e-05
# 1            0.000027                0.1       2.694363e-05
# 2            0.000027                0.2       2.693490e-05
# 3            0.000027                0.3       2.692582e-05
# 4            0.000027                0.4       2.691635e-05
# 5            0.000027                0.5       2.690649e-05
# 6            0.000027                0.6       2.689619e-05
# 7            0.000027                0.7       2.688544e-05
# 8            0.000027                0.8       2.687419e-05
# 9            0.000027                0.9       2.686243e-05
# 10           0.000027                1.0       2.685009e-05
# 11           0.000027                1.1       2.683715e-05
# 12           0.000027                1.2       2.682356e-05
# 13           0.000027                1.3       2.680927e-05
# 14           0.000027                1.4       2.679421e-05
# 15           0.000027                1.5       2.677832e-05
# 16           0.000027                1.6       2.676154e-05
# 17           0.000027                1.7       2.674378e-05
# 18           0.000027                1.8       2.672496e-05
# 19           0.000027                1.9       2.670497e-05
# 20           0.000027                2.0       2.668369e-05
# 21           0.000027                2.1       2.666100e-05
# 22           0.000027                2.2       2.663675e-05
# 23           0.000027                2.3       2.661077e-05
# 24           0.000027                2.4       2.658286e-05
# 25           0.000027                2.5       2.655278e-05
# 26           0.000027                2.6       2.652027e-05
# 27           0.000026                2.7       2.648502e-05
# 28           0.000026                2.8       2.644664e-05
# 29           0.000026                2.9       2.640469e-05
# 30           0.000026                3.0       2.635862e-05
# 31           0.000026                3.1       2.630775e-05
# 32           0.000026                3.2       2.625128e-05
# 33           0.000026                3.3       2.618814e-05
# 34           0.000026                3.4       2.611702e-05
# 35           0.000026                3.5       2.603618e-05
# 36           0.000026                3.6       2.594330e-05
# 37           0.000026                3.7       2.583522e-05
# 38           0.000026                3.8       2.570746e-05
# 39           0.000026                3.9       2.555347e-05
# 40           0.000025                4.0       2.536323e-05
# 41           0.000025                4.1       2.512066e-05
# 42           0.000025                4.2       2.479851e-05
# 43           0.000024                4.3       2.434834e-05
# 44           0.000024                4.4       2.368070e-05
# 45           0.000023                4.5       2.263146e-05
# 46           0.000021                4.6       2.092370e-05
# 47           0.000019                4.7       1.817092e-05
# 48           0.000014                4.8       1.396361e-05
# 49           0.000008                4.9       7.976362e-06
# 50           0.000000                5.0      -5.929231e-21

# %%
print(Ids_temp.iloc[:,3][50])
# Out:
# -6.988021814847978e-21

# %%
t = Ids_temp.iloc[:,0]
fig=plt.figure(figsize=(8,8), dpi= 100, facecolor='w', edgecolor='k')
ax2 = plt.axes()
line_temp_m20, = ax2.plot(t,Ids_temp.iloc[:,1],label="T=-20",linewidth=2.0)
#line_temp_5, = ax2.plot(t,Current_typ_temp.iloc[:,3],label="T=5",linewidth=3.0)
line_temp_30, = ax2.plot(t,Ids_temp.iloc[:,5],label="T=30",linewidth=2.0)
line_temp_55, = ax2.plot(t,Ids_temp.iloc[:,7],label="T=55",linewidth=2.0)
line_temp_80, = ax2.plot(t,Ids_temp.iloc[:,9],label="T=80",linewidth=2.0)
#ax2.legend(['A simple line'])
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('Напряжение сток исток, C')
plt.ylabel('Ток, A')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
Current_typ_vdd = pd.read_csv('imgs/Current_typ_vdd.csv', delimiter=',')
#Current_slow_temp = pd.read_csv('imgs/Current_slow_vdd.csv', delimiter=',')
#Current_fast_temp = pd.read_csv('imgs/Current_fast_vdd.csv', delimiter=',')
Current_rmin_vdd = pd.read_csv('imgs/Current_rmin_vdd.csv', delimiter=',')
Current_rmax_vdd = pd.read_csv('imgs/Current_rmax_vdd.csv', delimiter=',')

# %%
vdd = Current_typ_vdd.iloc[:,0]
fig=plt.figure(figsize=(8,8), dpi= 100, facecolor='w', edgecolor='k')
ax2 = plt.axes()
line_Current_typ_vdd, = ax2.plot(vdd,Current_typ_vdd.iloc[:,1],label="typ",linewidth=3.0)
#line_Current_slow_temp, = ax2.plot(t,Current_slow_temp.iloc[:,1],label="Current_slow_temp")
#line_Current_fast_temp, = ax2.plot(t,Current_fast_temp.iloc[:,1],label="Current_fast_temp")
line_Current_rmin_vdd, = ax2.plot(vdd,Current_rmin_vdd.iloc[:,1],label="rmin")
line_Current_rmax_vdd, = ax2.plot(vdd,Current_rmax_vdd.iloc[:,1],label="rmax")
#ax2.legend(['A simple line'])
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('Напряжение питания, В')
plt.ylabel('Ток, A')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
Comparator_tran = pd.read_csv('imgs/Comparator_tran_36n.csv', delimiter=',')

# %%
Comparator_tran
# Out:
#            /inm X  /inm Y        /inp X  /inp Y      /pout2 X      /pout2 Y  \
# 0    0.000000e+00     3.9  0.000000e+00     4.0  0.000000e+00  1.423693e+00
# 1    3.600000e-11     3.9  3.600000e-11     4.0  3.600000e-11  1.423694e+00
# 2    1.080000e-10     3.9  1.080000e-10     4.0  1.080000e-10  1.423695e+00
# 3    2.520000e-10     3.9  2.520000e-10     4.0  2.520000e-10  1.423698e+00
# 4    5.400000e-10     3.9  5.400000e-10     4.0  5.400000e-10  1.423721e+00
# ..            ...     ...           ...     ...           ...           ...
# 297  3.401657e-08     3.9  3.401657e-08     4.0  3.401657e-08 -1.946096e-06
# 298  3.432331e-08     3.9  3.432331e-08     4.0  3.432331e-08  4.308320e-07
# 299  3.478941e-08     3.9  3.478941e-08     4.0  3.478941e-08 -1.178418e-07
# 300  3.550941e-08     3.9  3.550941e-08     4.0  3.550941e-08  2.097376e-08
# 301  3.600000e-08     3.9  3.600000e-08     4.0  3.600000e-08  3.631006e-08
#
#          /pout1 X      /pout1 Y        /CLK X  /CLK Y       /M0/S X  \
# 0    0.000000e+00  1.662458e+00  0.000000e+00     0.0  0.000000e+00
# 1    3.600000e-11  1.662458e+00  3.600000e-11     0.0  3.600000e-11
# 2    1.080000e-10  1.662457e+00  1.080000e-10     0.0  1.080000e-10
# 3    2.520000e-10  1.662455e+00  2.520000e-10     0.0  2.520000e-10
# 4    5.400000e-10  1.662434e+00  5.400000e-10     0.0  5.400000e-10
# ..            ...           ...           ...     ...           ...
# 297  3.401657e-08 -6.705754e-07  3.401657e-08     5.0  3.401657e-08
# 298  3.432331e-08 -7.605872e-06  3.432331e-08     5.0  3.432331e-08
# 299  3.478941e-08  5.303928e-06  3.478941e-08     5.0  3.478941e-08
# 300  3.550941e-08 -3.537636e-06  3.550941e-08     5.0  3.550941e-08
# 301  3.600000e-08  8.578795e-07  3.600000e-08     5.0  3.600000e-08
#
#           /M0/S Y
# 0    5.908787e-05
# 1    5.908786e-05
# 2    5.908787e-05
# 3    5.908788e-05
# 4    5.908793e-05
# ..            ...
# 297 -2.004656e-07
# 298  1.854406e-07
# 299 -1.769380e-07
# 300  1.760579e-07
# 301 -1.717276e-07
#
# [302 rows x 12 columns]

# %%
time = Comparator_tran.iloc[:,0]
fig=plt.figure(figsize=(16,2), dpi= 200, facecolor='w', edgecolor='k')
ax2 = plt.axes()
line_out1, = ax2.plot(time,Comparator_tran.iloc[:,1],label="inm",linewidth=2.0)
line_out2, = ax2.plot(time,Comparator_tran.iloc[:,3],label="inp",linewidth=2.0)

#line_temp_5, = ax2.plot(t,Current_typ_temp.iloc[:,3],label="T=5",linewidth=3.0)
#ax2.legend(['A simple line'])
plt.legend(loc='upper right',prop={'size': 15})
plt.grid()
plt.xlabel('Время, C')
plt.ylabel('Напряжение, В')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
time = Comparator_tran.iloc[:,0]
fig=plt.figure(figsize=(16,5), dpi= 200, facecolor='w', edgecolor='k')
ax2 = plt.axes()
line_out3, = ax2.plot(time,Comparator_tran.iloc[:,9], '--',label="CLK",linewidth=1.5)
line_out4, = ax2.plot(time,Comparator_tran.iloc[:,7], '-',label="pout1",linewidth=2.5)
line_out5, = ax2.plot(time,Comparator_tran.iloc[:,5], '-',label="pout2",linewidth=2.5)

#line_temp_5, = ax2.plot(t,Current_typ_temp.iloc[:,3],label="T=5",linewidth=3.0)
#ax2.legend(['A simple line'])
plt.legend(loc='upper right',prop={'size': 16})
plt.grid()
plt.xlabel('Время, C')
plt.ylabel('Напряжение, В')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()

# %%
time = Comparator_tran.iloc[:,0]
fig2 = plt.figure(figsize=(16,9), dpi= 200, facecolor='w', edgecolor='k')
#fig2, axs = plt.subplots(2)
#fig2.suptitle('Vertically stacked subplots')
#fig2 = 
ax0 = plt.subplot()
ax1 = plt.subplot(
= ax0.plot(time,Comparator_tran.iloc[:,1],label="inm",linewidth=2.0)
<zv<<BXCNMz,./vlivnzm<xbc.<?zvxcbmn_out2, = ax0.plot(time,Comparator_tran.iloc[:,3],label="inp",linewidth=2.0)

line_out3, = ax1.plot(time,Comparator_tran.iloc[:,3],label="inp",linewidth=2.0)
line_out4, = ax1.plot(time,Comparator_tran.iloc[:,3],label="inp",linewidth=2.0)
#axs[0].plot(x, y)
#axs[1].plot(x, -y)NM<?3VXZ
#plt.legend(loc='upper right')
plt.grid()
#plt.xlabel('Температура, C')
#plt.ylabel('Ток, A')
#plt.figure(figsize=(10, 15))
#plt.figure(figsize=(2, 8), dpi=400)
plt.show()BCMNX2><xcvbmn,./z123zxcvbmn<zc>XVBNMz<xcvmzbnm,>?
# Out:
#   File "<ipython-input-26-097d1d7eb30a>", line 9
#     ax0.plot(time,Comparator_tran.iloc[:,3],label="inp",linewidth=2.0)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # CAMERA CAP
